# %%
import search_app as app
app.popular_hashtags()
# Out:
# Enter number of top hashtags to display: 10
# from db
# 0.344615
#                                                  hashtag  num_of_tweets
# 0              {'text': '25Aprile', 'indices': [15, 24]}           1452
# 1     {'text': 'AltaredellaPatria', 'indices': [75, 93]}            799
# 2            {'text': 'Mattarella', 'indices': [40, 51]}            799
# 3  {'text': 'PideAlmayaDiyeÇıkıp', 'indices': [95, 115]}            732
# 4            {'text': 'Mattarella', 'indices': [80, 91]}            654
# 5           {'text': 'Liberazione', 'indices': [53, 65]}            654
# 6              {'text': 'Corona', 'indices': [121, 128]}            307
# 7              {'text': 'Covid_19', 'indices': [87, 96]}            300
# 8                {'text': 'لبنان', 'indices': [97, 103]}            295
# 9               {'text': 'Iftar', 'indices': [103, 109]}            287
# key popular_hashtags_10
# key popular_hashtags_10
# key popular_hashtags_10
# key popular_hashtags_10
# ...
